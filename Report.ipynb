# %%
import pandas as pd

# %%
df = pd.read_csv("balance.txt", sep=" ")
print(df)
# Out:
#        Balance   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0    12.240798   14.891   3606     283      2   34         11    Male      No
# 1    23.283334  106.025   6645     483      3   82         15  Female     Yes
# 2    22.530409  104.593   7075     514      4   71         11    Male      No
# 3    27.652811  148.924   9504     681      3   36         11  Female      No
# 4    16.893978   55.882   4897     357      2   68         16    Male      No
# ..         ...      ...    ...     ...    ...  ...        ...     ...     ...
# 395   8.764984   12.096   4100     307      3   32         13    Male      No
# 396   9.943838   13.364   3838     296      5   65         17    Male      No
# 397  14.882078   57.872   4171     321      5   67         12  Female      No
# 398  12.001071   37.728   2525     192      1   44         13    Male      No
# 399  10.159598   18.701   5524     415      5   64          7  Female      No
#
#     Married         Ethnicity
# ...

# %% [markdown]
# Write the code needed to produce a report that provides the following information:
# * Compare the average income based on ethnicity.
# * On average, do married or single people have a higher balance?
# * What is the highest income in our dataset?
# * What is the lowest income in our dataset?
# * How many cards do we have recorded in our dataset? (Hint: use `sum()`)
# * How many females do we have information for vs how many males? (Hint: use `count()`For a list of all methods for computation of descriptive stats, explore the [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html#computations-descriptive-stats)).

# %%
ethnicity_ave_income = df.groupby('Ethnicity')['Income'].mean()
print(ethnicity_ave_income)
# Out:
# Ethnicity
# African American    47.682098
# Asian               44.187836
# Caucasian           44.671593
# Name: Income, dtype: float32

# %%
married_balance = df.loc[df["Married"] == "Yes", "Balance"].mean()
single_balance = df.loc[df["Married"] == "No", "Balance"].mean()

print("Married mean balance: ", married_balance)
print("Single mean balance: ", single_balance)

if married_balance > single_balance:
    print("Married has a higher balance.")
else:
    print("Single has a higher balance.")
# Out:
# Married mean balance:  13.393177
# Single mean balance:  13.493509
# Single individuals have a higher balance.

# %%
max_income = df['Income'].max()
print(max_income)
# Out:
# The maximum income is: 186.634

# %%
min_income = df['Income'].min()
print(min_income)
# Out:
# The minimum income is: 10.354

# %%
count = 0

for i in df['Cards']:
    print (i)
    count += i 
    print (count)
# Out:
# 2
# 2
# 3
# 5
# 4
# 9
# 3
# 12
# 2
# 14
# 4
# 18
# 2
# 20
# 2
# 22
# 5
# 27
# 3
# 30
# 4
# 34
# 3
# 37
# 1
# 38
# 1
# 39
# 2
# 41
# 3
# 44
# 3
# 47
# 3
# 50
# 1
# 51
# 2
# 53
# 4
# 57
# 1
# 58
# 3
# 61
# 5
# 66
# 3
# 69
# 5
# 74
# 6
# 80
# 2
# 82
# 2
# 84
# 4
# 88
# 4
# 92
# 5
# 97
# 2
# 99
# 4
# 103
# 2
# 105
# 3
# 108
# 2
# 110
# 2
# 112
# 4
# 116
# 4
# 120
# 3
# 123
# 2
# 125
# 2
# 127
# 1
# 128
# 3
# 131
# 3
# 134
# 2
# 136
# 2
# 138
# 6
# 144
# 4
# 148
# 3
# 151
# 2
# 153
# 1
# 154
# 4
# 158
# 2
# 160
# 2
# 162
# 7
# 169
# 4
# 173
# 2
# 175
# 4
# 179
# 2
# 181
# 3
# 184
# 2
# 186
# 4
# 190
# 2
# 192
# 4
# 196
# 4
# 200
# 4
# 204
# 2
# 206
# 4
# 210
# 4
# 214
# 2
# 216
# 1
# 217
# 4
# 221
# 4
# 225
# 2
# 227
# 1
# 228
# 1
# 229
# 3
# 232
# 2
# 234
# 3
# 237
# 1
# 238
# 3
# 241
# 3
# 244
# 4
# 248
# 4
# 252
# 1
# 253
# 4
# 257
# 4
# 261
# 3
# 264
# 4
# 268
# 3
# 271
# 4
# 275
# 2
# 277
# 3
# 280
# 5
# 285
# 1
# 286
# 4
# 290
# 2
# 292
# 5
# 297
# 1
# 298
# 3
# 301
# 2
# 303
# 6
# ...

# %%
female_count = len(df[df["Gender"] == "Female"])
male_count = len(df[df["Gender"] == "Male"])

print("Number of females:", female_count)
print("Number of males:", male_count)
# Out:
# Number of females: 207
# Number of males: 193
